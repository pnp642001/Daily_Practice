# %% [markdown]
# <a href="https://colab.research.google.com/github/pnp642001/Daily_Practice/blob/main/Day_2_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#creating a dataframe

df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#dropping passengerId

df.drop("PassengerId", inplace=True,axis=1)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df=pd.read_csv("taxonomy.csv.xls")
df.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash

# %%
#dropping the rows having NaN value in any column

df.dropna(inplace=True)
df.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash
# 5   101-02-03     Help Pay for Housing    101-02  Emergency Cash

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df_1=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df_1.drop("PassengerId",axis=1, inplace=True)

# %%
#creating a dataframe on the basis of survival

df_survived=df_1.groupby("Survived")

# %%
df_survived.sum()
# Out:
# <ipython-input-17-e89651bed227>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_survived.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            667   8219.67    162    159  16551.2294

# %%
df_survived.mean()
# Out:
# <ipython-input-18-aa88e84c7ea6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_survived.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
#finding the mean fare of all the class

df_1.groupby("Pclass").mean()
# Out:
# <ipython-input-19-ea3bdb1381df>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_1.groupby("Pclass").mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.629630  38.233441  0.416667  0.356481  84.154687
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
#transposing the above result for better understanding

df_1.groupby("Pclass").mean().transpose()
# Out:
# <ipython-input-20-c24bcdc4b412>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_1.groupby("Pclass").mean().transpose()
# Pclass            1          2          3
# Survived   0.629630   0.472826   0.242363
# Age       38.233441  29.877630  25.140620
# SibSp      0.416667   0.402174   0.615071
# Parch      0.356481   0.380435   0.393075
# Fare      84.154687  20.662183  13.675550

# %%
data= {'a': [1,2,3,4],
       'b':[5,6,7,8],
       'c': ['parth', 'patel', 'canada', 'usa']}

df_2=pd.DataFrame(data)
df_2
# Out:
#    a  b       c
# 0  1  5   parth
# 1  2  6   patel
# 2  3  7  canada
# 3  4  8     usa

# %%
#re-indexing

df_2=df_2.reindex([3,1,0,2])

df_2
# Out:
#    a  b       c
# 3  4  8     usa
# 1  2  6   patel
# 0  1  5   parth
# 2  3  7  canada

# %%
df_2['a'].mean()
# Out:
# 2.5

# %%
df_2['a'].median()
# Out:
# 2.5

# %%
df_2['a'].std()
# Out:
# 1.2909944487358056

# %%
df_2['a'].min()
# Out:
# 1

# %%
df_2['a'].max()
# Out:
# 4

# %%
# course_name = [‘Data Science’, ‘Machine Learning’, ‘Big Data’, ‘Data Engineer’]
# duration = [2,3,6,4]
# df = pd.DataFrame(data = {‘course_name’ : course_name, ‘duration’ : duration})

course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration=[2,3,6,4]

df_3=pd.DataFrame(data={'course_name': course_name, 'duration': duration})

df_3
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %%
# Write a code to print the data present in the second row of the dataframe

list(df_3['duration'])
# Out:
# [2, 3, 6, 4]

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.858006  0.837204  0.809717  0.192214  0.314387  0.531050
# 2  0.763999  0.984063  0.087447  0.272372  0.279043  0.592512
# 3  0.663183  0.762555  0.257718  0.629479  0.665961  0.530475
# 4  0.277333  0.569705  0.276343  0.085534  0.024936  0.576317
# 5  0.178135  0.523765  0.308079  0.407081  0.089664  0.873494
# 6  0.470834  0.924777  0.888230  0.680196  0.022404  0.950046

# %%
#mean of each and every column present in the dataframe.

df1.mean()
# Out:
# column_1    0.535248
# column_2    0.767011
# column_3    0.437922
# column_4    0.377813
# column_5    0.232732
# column_6    0.675649
# dtype: float64

# %%
# standard deviation of column, ‘column_2’

df1['column_2'].std()
# Out:
# 0.1871079007246313
